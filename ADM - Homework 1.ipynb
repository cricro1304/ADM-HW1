# %%
# Say "Hello, World!" With Python

if __name__ == '__main__':
    my_string = "Hello, World!"
    print(my_string)
# Out:
# Hello, World!

# %%
# Python If-Else

#!/bin/python3

import math
import os
import random
import re
import sys

if __name__ == '__main__':
    n = int(input().strip())
    
    if n >= 1 & n <= 100:
        if n%2 != 0:
            print("Weird")
        else:
            if n >= 2 and n <= 5:
                print("Not Weird")
            elif n >= 6 and n<= 20:
                print("Weird")
            else:
                print("Not Weird")
# Out:
# 3
# Weird

# %%
# Arithmetic Operatorsb

if __name__ == '__main__':
    a = int(input())
    b = int(input())
    if 1 <= a <= 10**10 and 1 <= b <= 10**10:
        sum = a+b
        difference = a-b
        product = a*b
        
        print(sum)
        print(difference)
        print(product)

# %%
# Python: Division

if __name__ == '__main__':
    a = int(input())
    b = int(input())
    
    print(a//b)
    print(a/b)

# %%
# Loops

if __name__ == '__main__':
    n = int(input())
    if n > 0:
        for i in range(0, n):
            print(i**2)

# %%
# Write a function

def is_leap(year):
    leap = False
    
    # Write your logic here
    if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
        leap = True 
    return leap

# %%
# Print Function

if __name__ == '__main__':
    n = int(input())
    for i in range(1, n+1):
        print(i, end='')
    print('')

# %%
# List Comprehensions

if __name__ == '__main__':
    x = int(input())
    y = int(input())
    z = int(input())
    n = int(input())
    
    coordinates = []
    for i in range(x + 1):
        for j in range(y + 1):
            for k in range(z + 1):
                if i + j + k != n:
                    coordinates.append([i, j, k])

    print(coordinates)

# %%
# Find the Runner-Up Score!

if __name__ == '__main__':
    n = int(input())
    arr = map(int, input().split())
    
    
    if 2 <= n <= 10:
        scores = []

        for i in range(n):
            for x in arr:
                if -100 <= x <= 100:
                    scores.append(x)
        
            scores.sort(reverse=True)
        
            runner_up_score = None
            for score in scores:
                if score < scores[0]:
                    runner_up_score = score
                    break
    
        print(runner_up_score)

# %%
# sWAP cASE

def swap_case(s):
    string = ""
    for elem in s:
        if elem.islower():
            string += elem.upper()
        elif elem.isupper():
            string += elem.lower()
        else:
            string += elem
            
    return string

# %%
# String Split and Join

def split_and_join(line):
    # write your code here
    line = line.split(" ")
    line = "-".join(line)
    return line

if __name__ == '__main__':
    line = input()
    result = split_and_join(line)
    print(result)

# %%
# What's Your Name?

def print_full_name(first, last):
    # Write your code here
    if len(first) <= 10 and len(last) <= 10:
        print("Hello", first, last+"!", "You just delved into python.")

# %%
# Mutations

def mutate_string(string, position, character):
    l = list(string)
    l[position] = character
    string = ''.join(l)
    return string

# %%
# Find a string

def count_substring(string, sub_string):
    if len(string) >= 1 and len(string) <= 200:
        i = 0
        j = 0
        k = 0
        while i <= len(string):
            if string[i:len(sub_string)+k] == sub_string:
                j += 1
            k += 1
            i += 1
            
    return j

# %%
# String Validators

if __name__ == '__main__':
    s = input()
    print(any(char.isalnum() for char in s))
    print(any(char.isalpha() for char in s))
    print(any(char.isdigit() for char in s))
    print(any(char.islower() for char in s))
    print(any(char.isupper() for char in s))

# %%
# Arrays

def arrays(arr):
    # complete this function
    # use numpy.array
    arr = numpy.array(arr)
    arr = arr[::-1]
    arr = arr.astype(float)
    return arr

# %%
# Shape and Reshape

import numpy
elements = input()
elements = elements.split()
if len(elements) == 9:
    elements = [int(element.strip("'")) for element in elements]
    elements = numpy.array(elements)
    print(numpy.reshape(elements,(3,3)))

# %%
# Introduction to Sets

def average(array):
    # your code goes here
    array = set(array)
    for x in array:
        array.add(x)
        
        total_height = sum(array)
        num_distinct_plants = len(array)
        average_height = total_height / num_distinct_plants
    
    return average_height

# %%
# Calendar Module

import datetime
import calendar

date_str = input()

date = datetime.datetime.strptime(date_str, "%m %d %Y").date()

weekday = date.weekday()

nameday = calendar.day_name[weekday]

print(nameday.upper())

# %%
# Finding the percentage

if __name__ == '__main__':
    n = int(input())
    student_marks = {}
    for _ in range(n):
        name, *line = input().split()
        scores = list(map(float, line))
        student_marks[name] = scores
    query_name = input()

output = list(student_marks[query_name])
avg = sum(output)/len(output)
print("%.2f" % avg)

# %%
# Symmetric Difference

M = int(input().strip())
set_m = set(map(int, input().strip().split(' ')))

N = int(input().strip())
set_n = set(map(int, input().strip().split(' ')))

symmetric_diff = set_m.symmetric_difference(set_n)
symmetric_diff = sorted(symmetric_diff)
symmetric_diff = set(symmetric_diff)
for x in symmetric_diff:
    print(x)

# %%
# Exceptions

T = int(input())

for i in range(T):
    line = input()
    a, b = line.split()
    
    try:
        a = int(a)
        b = int(b)
        
        print(a//b)      
    except ValueError as e:
        print(f"Error Code: {e}")        
    except ZeroDivisionError as e:
        print(f"Error Code: {e}")

# %%
# Min and Max


import numpy

element = input()

n_rows, n_columns = element.split()

n_rows = int(n_rows)
n_columns = int(n_columns)

array = numpy.zeros((n_rows, n_columns))

for i in range(n_rows):
    line = input()
    x, y = line.split()
    x = int(x)
    y = int(y)
    
    array[i] = (x, y)
    
array = array.astype(int) 
# print(array)

min_cols = numpy.min(array, axis=1)

max_min_cols = numpy.max(min_cols)

print(max_min_cols)

# %%
# Tuples

n = int(input())
integer_list = map(int, input().split())
t = tuple(integer_list)
print(hash(t))

# %%
# Nested Lists

if __name__ == '__main__':
    lista =[]
    scores = []
    for _ in range(int(input())):
        name = input()
        score = float(input())
        lista += [[name,score]]
        scores += [score]
    
    scores = list(set(scores))
    scores.sort()
    runner_up = scores[1]
    
    for name, score in sorted(lista):
        if score == runner_up:
            print(name)

# %%
# collections.Counter()

from collections import Counter

num_shoes = int(input())

shoes = Counter(map(int, input().split()))

customers = int(input())

income = 0
for i in range(customers):
    size, price = map(int, input().split())
    if shoes[size]:
        income += price
        shoes[size] -= 1

print(income)

# %%
# DefaultDict Tutorial

from collections import defaultdict
d = defaultdict(list)

n, m = map(int, input().split())

for i in range(n):
    d[input()].append(str(i+1))
for j in range(m):
    print(' '.join(d[input()]) or -1)

# %%
# Re.split()

regex_pattern = r"[,.]"

# %%
# Group(), Groups() & Groupdict()

import re
s = input()
m = re.search(r"([a-zA-Z0-9])\1", s)
if m:
    print(m.group(1))
else:
    print(-1)

# %%
# Collections.namedtuple()

from collections import namedtuple

n = int(input())
columns = input().split()
marks = 0
if n > 0 and n <= 100:
    for i in range(n):
        Student = namedtuple('Student', columns)
        
        MARKS, CLASS, NAME, ID = input().split()
        Student = Student(MARKS, CLASS, NAME, ID)
        marks += int(Student.MARKS)
    
    print(marks/n)

# %%
# Transpose and Flatten

import numpy

r, c = map(int, input().split())

l = []

for i in range(r):
    l.append(list(map(int, input().split())))

a = numpy.array(l)

print(numpy.transpose(a))
print(a.flatten())

# %%
# Concatenate 

import numpy

r1, r2, c = map(int, input().split())

l = []
j = []

for i in range(r1):
    l.append(list(map(int, input().split())))
for k in range(r2):
    j.append(list(map(int, input().split())))
    

a = numpy.array(l)
b = numpy.array(j)
d = numpy.concatenate((a, b), axis=0)
print(d)

# %%
# Zeros and Ones

import numpy

n = map(int, input().split())
n = list(n)
arr = numpy.array(n)
zero = numpy.zeros(arr, dtype=int)
uno = numpy.ones(arr, dtype=int)

print(zero)
print(uno)

# %%
# Zipped

stud, subj = input().split()

a = list()

for i in range(int(subj)):
    b = map(float, input().split())
    a.append(b)

for i in zip(*a):
    print(sum(i)/len(i))

# %%
# Athlete Sort

#!/bin/python3

import math
import os
import random
import re
import sys



if __name__ == '__main__':
    nm = input().split()

    n = int(nm[0])

    m = int(nm[1])

    arr = []

    for _ in range(n):
        arr.append(list(map(int, input().rstrip().split())))
        

    k = int(input())
    
    sorted_list = sorted(arr, key=lambda x: x[k])

    for i in sorted_list:
        print(*i)

# %%
# ginortS

string = input()

new_string = ""
for i in string:
    if i.islower():
        new_string += i
sorted_string = ''.join(sorted(new_string))

new_string1 = ""
for i in string:
    if i.isupper():
        new_string1 += i
sorted_string1 = ''.join(sorted(new_string1))

new_string2 = ""
for i in string:
    if i.isnumeric():
        if int(i) %2 != 0:
            new_string2 += i
sorted_string2 = ''.join(sorted(new_string2))

new_string3 = ""
for i in string:
    if i.isnumeric():
        if int(i) %2 == 0:
            new_string3 += i
sorted_string3 = ''.join(sorted(new_string3))

final_string = sorted_string+sorted_string1+sorted_string2+sorted_string3
print(final_string)

# %%
# Map and Lambda Function

cube = lambda x: x**3

def fibonacci(n):
    # return a list of fibonacci numbers
    fibonacci_num = []
    a, b = 0, 1
    if n >= 0 and n <= 15:
        for i in range(n):
            fibonacci_num.append(a)
            a, b = b, a+b
    return fibonacci_num

# %%
# Re.findall() & Re.finditer()

import re

string = input()

p = r'(?<=[bcdfghjklmnpqrstvwxtyzBCDFGHKLMNPQRSTVWXYZ])([AEIOUaeiou]{2,})(?=[bcdfghjklmnpqrstvwxtyzBCDFGHKLMNPQRSTVWXYZ])'

m = re.findall(p, string)

if m:
    for i in m:
        print(i)
else:
    print(-1)

# %%
# Validating phone numbers

import re 
n = int(input())

for i in range(n):
    if re.match(r'[789]\d{9}$', input()):
        print('YES')
    else:
        print("NO")

# %%
# XML 1 - Find the Score

def get_attr_number(node):
    # your code goes here
    s = 0
    for child in node.iter():
        s = s + len(child.attrib)
    return s

# %%
# XML2 - Find the Maximum Depth

maxdepth = 0
def depth(elem, level):
    global maxdepth
    # your code goes here
    if (level == maxdepth):
        maxdepth += 1
        
    for child in elem:
        depth(child, level + 1)

# %%
# Set .add()

n = int(input())

if n > 0 and n < 1000:
    s = set()
    for i in range(n):
        s.add(input())
    print(len(s))

# %%
# Set .discard(), .remove() & .pop()

n = int(input())
s = set(map(int, input().split()))
n_comando = int(input())
for i in range(n_comando):
    comando = input().split()
    if comando[0] == "remove":
        s.remove(int(comando[1]))
    elif comando[0] == "discard":
        s.discard(int(comando[1]))
    else:
        s.pop()
print(sum(s))

# %%
# Text Wrap

def wrap(string, max_width):
    if len(string) > 0 and len(string) < 1000 and max_width > 0 and max_width < len(string):
        for i in range(0, len(string)+1, max_width):
            text = string[i:i+max_width]
            if len(text) == max_width:
                print(text)
            else:
                return(text)

# %%
# Text Alignment

thickness = int(input()) #This must be an odd number
c = 'H'

#Top Cone
for i in range(thickness):
    print((c*i).rjust(thickness-1)+c+(c*i).ljust(thickness-1))

#Top Pillars
for i in range(thickness+1):
    print((c*thickness).center(thickness*2)+(c*thickness).center(thickness*6))

#Middle Belt
for i in range((thickness+1)//2):
    print((c*thickness*5).center(thickness*6))    

#Bottom Pillars
for i in range(thickness+1):
    print((c*thickness).center(thickness*2)+(c*thickness).center(thickness*6))    

#Bottom Cone
for i in range(thickness):
    print(((c*(thickness-i-1)).rjust(thickness)+c+(c*(thickness-i-1)).ljust(thickness)).rjust(thickness*6))

# %%
# Designer Door Mat

n, m = input().split()
n = int(n)
m = int(m)
for i in range(1, n+1):
    if i % 2 != 0 and i<n:
        print(('.|.'*i).center(m, '-'))
    if i == n:
        print(('WELCOME').center(m, '-'))
for i in range(n-1, 0, -1):
    if i % 2 != 0:
        print(('.|.'*i).center(m, '-'))

# %%
# Capitalize!

def solve(s):
    string = s.split(" ")
    result = ""
    
    for i in string:
        if i.isalpha():
            result += i.capitalize()
            if i != string[-1]:
                result += " "
        else:
            result += i
            if i != string[-1]:
                result += " "
                
    return result

# %%
# Standardize Mobile Number Using Decorators

def wrapper(f):
    def fun(l):
        # complete the function
        f = []
        for number in l:
            formatted_number = '+91 ' + number[-10:-5] + ' ' + number[-5:]
            f.append(formatted_number)
            
        sorted_numbers = sorted(f)
        
        for i in sorted_numbers:
            print(i)
        
    return fun

# %%
# Decorators 2 - Name Directory

def person_lister(f):
    def inner(people):
        # complete the function
        sorted_people = sorted(people, key=lambda x: int(x[2]))
        result = []
        for p in sorted_people:
            result.append(f(p))
        return result
            
    return inner

# %%
# Array Mathematics

import numpy as np

r, c = map(int, input().split())

a = []
for _ in range(r):
    row = list(map(int, input().split()))
    a.append(row)
a = np.array(a)

b = []
for _ in range(r):
    row = list(map(int, input().split()))
    b.append(row)
b = np.array(b)

print(a+b)
print(a-b)
print(a*b)
print(a//b)
print(a % b)
print(a**b)

# %%
# Floor, Ceil and Rint

import numpy
numpy.set_printoptions(legacy='1.13')

a = numpy.array(input().split(), float)

print(numpy.floor(a))
print(numpy.ceil(a))
print(numpy.rint(a))

# %%
# Sum and Prod

import numpy

r, c = map(int, input().split())
l = []
for i in range(r):
    l.append(input().split())

l = numpy.array(l, int)
somma = numpy.sum(l, axis=0)

prodotto = numpy.product(somma)
print(prodotto)

# %%
# String Formatting

def print_formatted(number):
    # your code goes here
    width = len(bin(number)[2:])
    
    for i in range(1, number+1):
        decimal = str(i)
        octal = oct(i)[2:]
        hexadecimal = hex(i)[2:].upper()
        binary = bin(i)[2:]
        print(decimal.rjust(width), octal.rjust(width), hexadecimal.rjust(width), binary.rjust(width))

# %%
# Dot and Cross

import numpy

r = int(''.join(map(str, input())))

a = []
for _ in range(r):
    row = list(map(int, input().split()))
    a.append(row)
a = numpy.array(a)
# print(a)

b = []
for _ in range(r):
    row = list(map(int, input().split()))
    b.append(row)
b = numpy.array(b)

risultato = numpy.dot(a, b)
print(risultato)

# %%
# Inner and Outer

import numpy

arr1 = numpy.array(input().split(), int)
arr2 = numpy.array(input().split(), int)

inner = numpy.inner(arr1, arr2)
outer = numpy.outer(arr1, arr2)

print(inner)
print(outer)

# %%
# Polynomials

import numpy

polyn = []
for i in input().split():
    polyn.append(float(i))

risultato = numpy.polyval(polyn, float(input()))
print(risultato)

# %%
# Linear Algebra

import numpy
numpy.set_printoptions(legacy='1.13')

r = int(input())
# print(r)
arr = []
for i in range(r):
    arr.append(input().split())

arr = numpy.array(arr, float)
det = numpy.linalg.det(arr)
print(det)

# %%
# Eye and Identity

import numpy
numpy.set_printoptions(legacy='1.13')

r, c = map(int, input().split())

ris = numpy.eye(r, c, k=0)

print(ris)

# %%
# Time Delta

#!/bin/python3

import math
import os
import random
import re
import sys
from datetime import datetime

# Complete the time_delta function below.
def time_delta(t1, t2):
    format_str = "%a %d %b %Y %H:%M:%S %z"
    
    t1 = datetime.strptime(t1, format_str)
    t2 = datetime.strptime(t2, format_str)
    time_dif = t1 - t2
    time_dif = str(int(abs(time_dif.total_seconds())))
    return time_dif

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    t = int(input())

    for t_itr in range(t):
        t1 = input()

        t2 = input()
        
        print(t1, t2)

        delta = time_delta(t1, t2)

        fptr.write(delta + '\n')

    fptr.close()

# %%
# Set .union() Operation

n = int(input())

stud_en = set(map(int, input().split()))

k = int(input())

stud_fr = set(map(int, input().split()))

stud_tot = stud_en.union(stud_fr)
print(len(stud_tot))

# %%
# Set .intersection() Operation

n = int(input())
stud_en = set(map(int, input().split()))

k = int(input())
stud_fr = set(map(int, input().split()))

stud_tot = stud_en.intersection(stud_fr)
print(len(stud_tot))

# %%
# Set .difference() Operation

n = int(input())
stud_en = set(map(int, input().split()))

k = int(input())
stud_fr = set(map(int, input().split()))

stud_tot = stud_en.difference(stud_fr)
print(len(stud_tot))

# %%
# Set .symmetric_difference() Operation

n = int(input())
stud_en = set(map(int, input().split()))

k = int(input())
stud_fr = set(map(int, input().split()))

stud_tot = stud_en.symmetric_difference(stud_fr)
print(len(stud_tot))

# %%
# Set Mutations

n = int(input())

set_a = set(map(int, input().split()))

k = int(input())

for i in range(k):
    op_name = input().split()
    set_b = set(map(int, input().split()))
    eval('set_a.{}({})'.format(op_name[0], set_b))

print(sum(set_a))

# %%
# The Captain's Room

n = int(input())

room_num = list(map(int, input().split()))

mai_visto = set()
visto = set()

for x in room_num:
    if x in mai_visto:
        visto.add(x)
    else:
        mai_visto.add(x)
        
print(sum(mai_visto.difference(visto)))

# %%
# Check Subset

t = int(input())

for i in range(t):
    num_a = int(input())
    set_a = set(map(int, input().split()))
    
    num_b = int(input())
    set_b = set(map(int, input().split()))
    
    is_subset = set_a.issubset(set_b)
    print(is_subset)

# %%
# Check Strict Superset

set_a = set(map(int, input().split()))

n = int(input())
count = 0

for i in range(n):
    set_b = set(map(int, input().split()))
    if set_a.issuperset(set_b):
        count += 1

if count == n:
    print('True')
else:
    print('False')

# %%
# No Idea!

n, m = map(int, input().split())
arr = list(map(int, input().split()))

set_a = set(map(int, input().split()))
set_b = set(map(int, input().split()))

happiness = 0
for i in arr:
    if i in set_a:
        happiness += 1
    if i in set_b:
        happiness -= 1

print(happiness)

# %%
# Collections.OrderedDict()

from collections import OrderedDict

n = int(input())
ordered_dictionary = OrderedDict()

for i in range(n):
    a = input().split()
    item_name = " ".join(a[:-1])
    net_price = int(a[-1])
    if item_name in ordered_dictionary:
        ordered_dictionary[item_name] += net_price
    else:
        ordered_dictionary[item_name] = net_price

for key, value in ordered_dictionary.items():
    print(key, value)

# %%
# The Minion Game

def minion_game(string):
    s=len(string)
    vowel = 0
    consonant = 0
     
    for i in range(s):
        if string[i] in 'AEIOU':
           vowel+=(s-i)
        else:
           consonant+=(s-i)
                
    if vowel < consonant:
        print('Stuart ' + str(consonant))
    elif vowel > consonant:
        print('Kevin ' + str(vowel))
    else:
        print('Draw')

# %%
# Alphabet Rangoli

def print_rangoli(size):

    alphabet = "abcdefghijklmnopqrstuvwxyz"
    lista = []
    for i in range(size):
        lista.append(alphabet[i])
    integers = list(range(size))
    integers = integers[:-1]+integers[::-1]
    for i in integers:
        ran = lista[-(i+1):]
        row = ran[::-1]+ran[1:]
        print("-".join(row).center(n*4-3, "-"))

# %%
# Collections.deque()

from collections import deque

n = int(input())

d = deque()

for i in range(n):
    comando = input().split()
    if len(comando) == 2:
        eval("d.{}({})".format(comando[0], comando[1]))
    else:
        eval("d.{}()".format(comando[0]))

print(" ".join(map(str, d)))

# %%
# Company Logo

#!/bin/python3

import math
import os
import random
import re
import sys

from collections import Counter

if __name__ == '__main__':
    s = input()
    s = sorted(s)
    char = Counter(s)
    most_common_chars = char.most_common(3)
    
    if len(most_common_chars) >= 3:
        for i in most_common_chars:
            i = " ".join(map(str, i))
            print(i)

# %%
# Word Order

from collections import Counter

n = int(input())

l = []
for i in range(n):
    l.append(input().strip())

words = Counter(l)

print(len(words))

print(*words.values())

# %%
# Hex Color Code

import re

n = int(input())

for i in range(n):
    i = input()
    exp = re.findall(r':?.(#[0-9a-fA-F]{6}|#[0-9a-fA-F]{3})', i)
    
    if exp:
        for x in exp:
            print(x)

# %%
# Merge the Tools!

def merge_the_tools(string, k):

    for i in range(0, len(string), k):
        substring = ""
        for j in string[i:k+i]:
            if j not in substring:
                substring += j
        print(substring)

# %%
# Birthday Cake Candles

#!/bin/python3

import math
import os
import random
import re
import sys

def birthdayCakeCandles(candles):
    # Write your code here
    
    count = 0
    mass = max(candles)
    for i in candles:
        if i == mass:
            count += 1
    
    return count
       

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    candles_count = int(input().strip())

    candles = list(map(int, input().rstrip().split()))

    result = birthdayCakeCandles(candles)

    fptr.write(str(result) + '\n')

#     fptr.close()

# %%
# Number Line Jumps

#!/bin/python3

import math
import os
import random
import re
import sys


def kangaroo(x1, v1, x2, v2):
    # Write your code here
    if v1-v2 > 0 and (x2 - x1) % (v1 - v2) == 0:
        return 'YES'
    else:
        return 'NO'
    

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    first_multiple_input = input().rstrip().split()

    x1 = int(first_multiple_input[0])

    v1 = int(first_multiple_input[1])

    x2 = int(first_multiple_input[2])

    v2 = int(first_multiple_input[3])

    result = kangaroo(x1, v1, x2, v2)

    fptr.write(result + '\n')

    fptr.close()

# %%
# Viral Advertising

#!/bin/python3

import math
import os
import random
import re
import sys


def viralAdvertising(n):
    # Write your code here
    share = 5
    cum_likes = 0
    for i in range(1, n+1):
        liked = share//2
        cum_likes+=liked
        share = liked*3
    return cum_likes

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    n = int(input().strip())

    result = viralAdvertising(n)

    fptr.write(str(result) + '\n')

    fptr.close()

# %%
# Insertion Sort - Part 1

#!/bin/python3

import math
import os
import random
import re
import sys

def insertionSort1(n, arr):
    val = arr[n - 1]
    i = n - 2 

    while i >= 0 and arr[i] > val:
        arr[i+1] = arr[i]
        for j in range(n):
            print(arr[j], end=' ')
        print()
        i -= 1

    arr[i+1] = val

    for j in range(n):
        print(arr[j], end=' ')


if __name__ == '__main__':
    n = int(input().strip())

    arr = list(map(int, input().rstrip().split()))

    insertionSort1(n, arr)

# %%
# Insertion Sort - Part 2

#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'insertionSort2' function below.
#
# The function accepts following parameters:
#  1. INTEGER n
#  2. INTEGER_ARRAY arr
#

def insertionSort2(n, arr):
    for i in range(1, n):
        val = arr[i]
        j = i - 1

        while j >= 0 and arr[j] > val:
            arr[j + 1] = arr[j]
            j -= 1

        arr[j + 1] = val

        for num in arr:
            print(num, end=' ')
        print()

if __name__ == '__main__':
    n = int(input().strip())

    arr = list(map(int, input().rstrip().split()))

    insertionSort2(n, arr)

# %%
# Recursive Digit Sum

#!/bin/python3

import math
import os
import random
import re
import sys

def superDigit(n, k):
    # Write your code here
     return 1 + (k * sum(int(x) for x in n) - 1) % 9

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    first_multiple_input = input().rstrip().split()

    n = first_multiple_input[0]

    k = int(first_multiple_input[1])

    result = superDigit(n, k)

    fptr.write(str(result) + '\n')

    fptr.close()

# %%
# Piling Up!

T = int(input())

for x in range(T):
    n = int(input())
    lista = list(map(int, input().split()))
    m = max(lista)
    
    for x in range(len(lista)+1):
        if len(lista)==0:
            print("Yes")
        elif m <= lista[0]:
            lista.remove(lista[-1])
        elif m <= lista[-1]:
            lista.remove(lista[0])
        else:
            print("No")
            break

# %%
# HTML Parser - Part 1

from html.parser import HTMLParser

# create a subclass and override the handler methods
class MyHTMLParser(HTMLParser):
    
    def handle_starttag(self, tag, attrs):
        print("Start :", tag)
        for i in attrs:
            print('->', i[0], '>', i[1])
            
    def handle_endtag(self, tag):
        print("End   :", tag)
        
    def handle_startendtag(self, tag, attrs):
        print("Empty :", tag)
        for i in attrs:
            print('->', i[0], '>', i[1])
        

# instantiate the parser and fed it some HTML
parser = MyHTMLParser()

i = int(input())

for i in range(i):
    parser.feed(input())

# %%
# HTML Parser - Part 2

from html.parser import HTMLParser

class MyHTMLParser(HTMLParser):
    def handle_comment(self, data):
        prefix = 'Multi' if '\n' in data else 'Single'
        print(f">>> {prefix}-line Comment", data, sep="\n")
    
    def handle_data(self, data):
        if data != "\n":
            print(">>> Data")
            print(data)
            
html = ""

for i in range(int(input())):
    html += input().rstrip()
    html += '\n'
  
parser = MyHTMLParser()
parser.feed(html)
parser.close()

# %%
# Detect HTML Tags, Attributes and Attribute Values

from html.parser import HTMLParser

class MyHTMLParser(HTMLParser):
    
    def custom_print_attrs(self, attrs):
        if attrs:
            for x in attrs:
                print('->', x[0], '>', x[1])
    
    def handle_starttag(self, tag, attrs):
        print(tag)
        self.custom_print_attrs(attrs)

    def handle_startendtag(self, tag, attrs):
        print(tag)
        self.custom_print_attrs(attrs)

html_parser = MyHTMLParser()

pages = []
n = int(input())

for i in range(n):
    pages.append(input())

for page in pages:
    html_parser.feed(page)

# %%
# Validating UID

import re

n = int(input())

pattern = pattern = r'^(?=(?:.*[A-Z]){2,})(?=(?:.*\d){3,})(?!.*(.).*\1)[\w]{10}$'

for i in range(n):
    if re.match(pattern, input()):
        print('Valid')
    else:
        print('Invalid')

# %%
# Validating Roman Numerals

regex_pattern = r"^(M{0,3}(CM|CD|D?C{0,3})(XC|XL|L?X{0,3})(IX|IV|V?I{0,3}))$"

# %%
# Validating and Parsing Email Addresses

import re
n = int(input())
pattern = r'^<[A-Za-z](\w|-|\.|_)+@[A-Za-z]+\.[A-Za-z]{1,3}>$'

for i in range(n):
    name, email = input().split()
    if re.match(pattern, email):
        print(name, email)

# %%
# Validating Credit Card Numbers

import re

n = int(input())
pattern = r'^(?!.*(\d)(?:-?\1){3})([456]\d{3}-?\d{4}-?\d{4}-?\d{4}|[456]\d{16})$'

for i in range(n):
    card = input()
    if re.match(pattern, card):
        print("Valid")
    else:
        print("Invalid")

# %%
# Re.start() & Re.end()

import re
string = input()
substring = input()

pattern = re.compile(substring)
p = pattern.search(string)

if p:
  while p:
    print(f"({p.start()}, {p.end()-1})")
    p = pattern.search(string, p.start()+1)
        
else:
  print("(-1, -1)")

# %%
# Detect Floating Point Number

import re

n = int(input())
pattern = r'^((\+|-)?\d*)?(\.)\d+$'

for i in range(n):
    floatn = input()
    a = re.match(pattern, floatn)
    print(bool(a))

# %%
# Regex Substitution

import re

n = int(input())

for i in range(n):
    a = input()
    print(re.sub(r'(?<= )(&&|\|\|)(?= )', lambda x: 'and' if x.group() == '&&' else 'or', a))
